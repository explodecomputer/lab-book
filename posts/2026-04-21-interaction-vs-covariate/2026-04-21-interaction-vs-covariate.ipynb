# %% [markdown]
# ---
# title: "Stratification by APOE alleles vs adjustment"
# date: 2026-04-21
# ---

# %% [markdown]
# # Stratification by APOE alleles vs adjustment
#
# One way to understand how APOE influences Alzheimer's disease risk is to estimate the effect of an exopsure on AD risk in the E4 allele group vs other allele groups.
